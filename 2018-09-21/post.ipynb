# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/nursery/nursery.data'
columns = ['parents', 'has_nurs', 'form', 'children', 'housing', 'finance', 'social', 'health', 'target']

df = pd.read_csv(url, names=columns)
df.head()
# Out:
#   parents has_nurs      form children     housing     finance         social  \
# 0   usual   proper  complete        1  convenient  convenient        nonprob
# 1   usual   proper  complete        1  convenient  convenient        nonprob
# 2   usual   proper  complete        1  convenient  convenient        nonprob
# 3   usual   proper  complete        1  convenient  convenient  slightly_prob
# 4   usual   proper  complete        1  convenient  convenient  slightly_prob
#
#         health     target
# 0  recommended  recommend
# 1     priority   priority
# 2    not_recom  not_recom
# 3  recommended  recommend
# 4     priority   priority

# %%
X = pd.get_dummies(df.loc[:, df.columns != 'target'])
y = df[['target']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
catboost = CatBoostClassifier(iterations=1000,
                              learning_rate=0.05,
                              depth=10,
                              random_seed = 42,
                              bagging_temperature = 0.2,
                              od_type='Iter',
                              metric_period = 50,
                              od_wait=20)

# %%
y_train
# Out:
#            target
# 2516    not_recom
# 10545  spec_prior
# 9953    not_recom
# 3094   spec_prior
# 6902    not_recom
# 7593   spec_prior
# 1190    not_recom
# 10372    priority
# 11847  spec_prior
# 12653   not_recom
# 4194   spec_prior
# 7070    not_recom
# 3948   spec_prior
# 9174     priority
# 5643   very_recom
# 4074   spec_prior
# 10844   not_recom
# 1506     priority
# 3902    not_recom
# 11227  spec_prior
# 9653    not_recom
# 10069  spec_prior
# 9473    not_recom
# 12674   not_recom
# 12639    priority
# 6482    not_recom
# 794     not_recom
# 730      priority
# 1344     priority
# 7049    not_recom
# ...           ...
# 8666    not_recom
# 11096   not_recom
# 6396   spec_prior
# 12309  spec_prior
# 3385   spec_prior
# 4555     priority
# 1184    not_recom
# 6420     priority
# 5051    not_recom
# 5311     priority
# 2433   very_recom
# 6949   spec_prior
# 10583   not_recom
# 769      priority
# 1685    not_recom
# 8322   spec_prior
# 11111   not_recom
# 11363   not_recom
# 11636   not_recom
# 5578     priority
# 4426     priority
# 466      priority
# 6265     priority
# 5734     priority
# 11284  spec_prior
# 11964  spec_prior
# 5191     priority
# 5390    not_recom
# 860     not_recom
# 7270   spec_prior
#
# [9720 rows x 1 columns]

# %%
catboost.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-fdd330f548a7> in <module>()
# ----> 1 catboost.fit(X_train, y_train)
#
# ~/miniconda3/envs/ds/lib/python3.6/site-packages/catboost/core.py in fit(self, X, y, cat_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval)
#    2117         self._fit(X, y, cat_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    2118                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
# -> 2119                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval)
#    2120         return self
#    2121
#
# ~/miniconda3/envs/ds/lib/python3.6/site-packages/catboost/core.py in _fit(self, X, y, cat_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval)
#    1054         _check_train_params(params)
#    1055
# -> 1056         train_pool = _build_train_pool(X, y, cat_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#    1057         if train_pool.is_empty_:
#    1058             raise CatboostError("X is empty.")
#
# ~/miniconda3/envs/ds/lib/python3.6/site-packages/catboost/core.py in _build_train_pool(X, y, cat_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#     663             raise CatboostError("y has not initialized in fit(): X is not catboost.Pool object, y must be not None in fit().")
#     664         train_pool = Pool(X, y, cat_features=cat_features, pairs=pairs, weight=sample_weight, group_id=group_id,
# --> 665                           group_weight=group_weight, subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline)
#     666     return train_pool
#     667
#
# ~/miniconda3/envs/ds/lib/python3.6/site-packages/catboost/core.py in __init__(self, data, label, cat_features, column_description, pairs, delimiter, has_header, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     293                         )
#     294
# --> 295                 self._init(data, label, cat_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names)
#     296         super(Pool, self).__init__()
#     297
#
# ~/miniconda3/envs/ds/lib/python3.6/site-packages/catboost/core.py in _init(self, data, label, cat_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names)
#     644         if feature_names is not None:
#     645             self._check_feature_names(feature_names, features_count)
# --> 646         self._init_pool(data, label, cat_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names)
#     647
#     648
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._set_label()
#
# ValueError: could not convert string to float: 'not_recom'
